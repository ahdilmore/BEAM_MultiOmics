# %%
import pandas as pd
import qiime2 as q2
from biom import Table
import numpy as np
from biom.util import biom_open

# plotting
import matplotlib
import seaborn as sns
import matplotlib.pyplot as plt

plt.style.use('ggplot')
# %matplotlib inline

# %% [markdown]
# # import metabolomics subsets

# %%
metab_metadata = pd.read_csv('../data/metabolomics/BEAM_metadata_KAW.csv', index_col='Sample.Barcode')

metab_metadata = metab_metadata[~metab_metadata.SubjectID.isin(['3JEBA000908'])]
metab_metadata.index = metab_metadata.index.astype(str)
metab_metadata = metab_metadata[metab_metadata['First.Diet'].isin(['1','2'])]
metab_metadata['First.Diet'] = metab_metadata['First.Diet'].astype(int)

metab_metadata['diet_nocross'] = metab_metadata['Diet.Type.Detailed'].replace({'Keto-to-AHA Crossover':'AHA Diet', 'AHA-to-Keto Crossover':'Ketogenic Diet'})
metab_metadata['timepoint_encoded'] = metab_metadata['Study_TP']
metab_metadata['first_diet'] = metab_metadata['First.Diet']

metab_metadata_stool = metab_metadata[metab_metadata['Sample.Type'] == 'Stool']

metab_metadata.head(5)
# Out:
#                Sample.Type    SubjectID  StudyID  Status  First.Diet  Age  \
# Sample.Barcode
# 5555659              Stool  3AWFR000081  1263001       1           1   62
# 5555660              Stool  3AWFR000081  1263001       1           1   62
# 5555661              Stool  3AWFR000081  1263001       1           1   62
# 5555662              Stool  3AWFR000081  1263001       1           1   62
# 5555663              Stool  3AWFR000081  1263001       1           1   62
#
#                 Gender  BMI_pbl  MemDx Visit.Type.Stool  ... StudyID_1  \
# Sample.Barcode                                           ...
# 5555659              1    27.92  MCI-A            Pre 1  ...   1263001
# 5555660              1    27.92  MCI-A           Post 1  ...   1263001
# 5555661              1    27.92  MCI-A     FU 1 / Pre 2  ...   1263001
# 5555662              1    27.92  MCI-A           Post 2  ...   1263001
# 5555663              1    27.92  MCI-A             FU 2  ...   1263001
#
#                Visit.Type.Blood  Cog.Visit.Date     Diet.Type.Detailed  \
# Sample.Barcode
# 5555659                PREA-COG      02/04/2015         Ketogenic Diet
# 5555660               POSTA-COG       3/24/2015         Ketogenic Diet
# 5555661                PREB-COG      05/05/2015  Keto-to-AHA Crossover
# 5555662               POSTB-COG       6/17/2015               AHA Diet
# 5555663                POSTB-FU      08/03/2015               AHA Diet
#
#                                               Visit.Type.Detailed Study_TP  \
# Sample.Barcode
# 5555659                                Ketogenic Diet Preliminary        1
# 5555660                                  Ketogenic Diet Post-Diet        2
# 5555661         Ketogenic 6-Week Follow-up & AHA Diet Preliminary        3
# 5555662                                        AHA Diet Post-Diet        4
# 5555663                                 AHA 6-Week Follow-up Only        5
#
#                      filename    diet_nocross timepoint_encoded  first_diet
# Sample.Barcode
# 5555659         5555659.mzXML  Ketogenic Diet                 1           1
# 5555660         5555660.mzXML  Ketogenic Diet                 2           1
# 5555661         5555661.mzXML        AHA Diet                 3           1
# 5555662         5555662.mzXML        AHA Diet                 4           1
# 5555663         5555663.mzXML        AHA Diet                 5           1
#
# [5 rows x 24 columns]

# %%
sns.pointplot(y='first_diet', x='timepoint_encoded', hue='diet_nocross', data=metab_metadata)

plt.show()

# %% [markdown]
# # match the microbiome data

# %%
metadata = pd.read_csv('../data/13662_20210620-201815.txt', sep='\t', index_col=0)

# drop one timepoint subject
metadata = metadata[~metadata.host_subject_id.isin(['3JEBA000908'])]

# drop the dropout subjects
metadata = metadata[metadata['first_diet'].isin(['1','2'])]
metadata['first_diet'] = metadata['first_diet'].astype(int)

# fix and clean data 
metadata = metadata[metadata.host_body_habitat == 'UBERON:feces'] # drop blank
metadata['cog'] = metadata.memdx.replace({'NC-SC':'NC','MCI-A':'MCI','MCI-MDA':'MCI'}) # merge cogs
metadata['timepoint'] = metadata.timepoint.replace({'FU 2 /Pre 1':'FU 2 / Pre 1'}) # fix typo

# add diet from metabolomics data by barcode
diet_map = metab_metadata['Diet.Type.Detailed'].to_dict()
metadata['diet'] = [diet_map[ind.replace('13662.','')] for ind in metadata.index]
metadata['diet_nocross'] = metadata.diet.replace({'Keto-to-AHA Crossover':'AHA Diet', 'AHA-to-Keto Crossover':'Ketogenic Diet'})

#get timepoint map from metabolomics (comes from "BEAM Diet Guide.doc")
timepoint_map =  metab_metadata['Study_TP'].to_dict()
metadata['timepoint_encoded'] = [int(timepoint_map[ind.replace('13662.','')]) for ind in metadata.index]


metadata.head(5)
# Out:
#               age anonymized_name bmi_pbl           box_name cog_visit_date  \
# sample_name
# 13662.5555659  62         1263001   27.92  31102 Stool Box 1         2/4/15
# 13662.5555660  62         1263001   27.92  31102 Stool Box 1        3/24/15
# 13662.5555661  62         1263001   27.92  31102 Stool Box 1         5/5/15
# 13662.5555662  62         1263001   27.92  31102 Stool Box 1        6/17/15
# 13662.5555663  62         1263001   27.92  31102 Stool Box 1         8/3/15
#
#               collection_timestamp                            description  \
# sample_name
# 13662.5555659           2015-02-11         fecal sample Pre 1 3AWFR000081
# 13662.5555660           2015-03-25        fecal sample Post 1 3AWFR000081
# 13662.5555661           2015-05-07  fecal sample FU 1 / Pre 2 3AWFR000081
# 13662.5555662           2015-06-22        fecal sample Post 2 3AWFR000081
# 13662.5555663           2015-08-04          fecal sample FU 2 3AWFR000081
#
#                dna_extracted  elevation           empo_1  ... taxon_id  \
# sample_name                                               ...
# 13662.5555659           True        300  Host-associated  ...   408170
# 13662.5555660           True        300  Host-associated  ...   408170
# 13662.5555661           True        300  Host-associated  ...   408170
# 13662.5555662           True        300  Host-associated  ...   408170
# 13662.5555663           True        300  Host-associated  ...   408170
#
#                   timepoint     title     tube_id uom visit_type  cog  \
# sample_name
# 13662.5555659         Pre 1  BEAM_U19  0005555659  mg   PreA-Cog  MCI
# 13662.5555660        Post 1  BEAM_U19  0005555660  mg  POSTA-COG  MCI
# 13662.5555661  FU 1 / Pre 2  BEAM_U19  0005555661  mg   PREB-COG  MCI
# 13662.5555662        Post 2  BEAM_U19  0005555662  mg  POSTB-COG  MCI
# 13662.5555663          FU 2  BEAM_U19  0005555663  mg   POSTB-FU  MCI
#
#                                 diet    diet_nocross timepoint_encoded
# sample_name
# 13662.5555659         Ketogenic Diet  Ketogenic Diet                 1
# 13662.5555660         Ketogenic Diet  Ketogenic Diet                 2
# 13662.5555661  Keto-to-AHA Crossover        AHA Diet                 3
# 13662.5555662               AHA Diet        AHA Diet                 4
# 13662.5555663               AHA Diet        AHA Diet                 5
#
# [5 rows x 63 columns]

# %%
sns.pointplot(y='first_diet', x='timepoint_encoded', hue='diet_nocross', data=metadata)

plt.show()

# %%
# import 16S
bt = q2.Artifact.load('../data/16S/120736_feature-table.qza').view(Table)

# match the metadata 
shared_samples = set(bt.ids()) & set(metadata.index)
metadata_16S = metadata.copy().reindex(shared_samples)

# filte table
bt = bt.filter(shared_samples)

# filter and match the table
n_features, n_samples = bt.shape
min_feature_frequency = 0
min_feature_count = 0
min_sample_count = 100
def frequency_filter(val, id_, md):
    return (np.sum(val > 0) / n_samples) > (min_feature_frequency / 100)
def observation_filter(val, id_, md):
        return sum(val) > min_feature_count
bt = bt.filter(observation_filter, axis='observation')
bt = bt.filter(frequency_filter, axis='observation')
bt = bt.filter(bt.ids()[(bt.sum('sample') > min_sample_count)])

table = q2.Artifact.import_data('FeatureTable[Frequency]', bt)
table.save('../data/16S/16S-matched-table.qza')

with biom_open('../data/16S/16S-matched-table.biom', 'w') as f:
    table.view(Table).to_hdf5(f, "filt")

metadata_16S.to_csv('../data/16S/16S-matched-metadata.tsv', sep='\t')

metadata_16S.index = metadata_16S.index.astype(str)
metadata_16S = metadata_16S.drop(['dna_extracted','physical_specimen_remaining'], axis=1)
q2.Metadata(metadata_16S).save('../data/16S/16S-matched-metadata.qza')

bt
# Out:
# 7397 x 96 <class 'biom.table.Table'> with 26944 nonzero entries (3% dense)

# %%
pd.DataFrame({t:tdf.cog.value_counts() for t, tdf in metadata_16S.groupby(['timepoint_encoded','diet'])}).T
# Out:
#                          MCI  NC
# 1 AHA Diet                 3   5
#   Ketogenic Diet           6   5
# 2 AHA Diet                 3   5
#   Ketogenic Diet           6   6
# 3 AHA-to-Keto Crossover    3   5
#   Keto-to-AHA Crossover    6   6
# 4 AHA Diet                 6   6
#   Ketogenic Diet           3   4
# 5 AHA Diet                 6   6
#   Ketogenic Diet           2   4

# %%
pd.DataFrame({t:tdf.diet.value_counts() for t, tdf in metadata_16S.groupby(['host_subject_id'])}).T
# Out:
#              AHA Diet  AHA-to-Keto Crossover  Keto-to-AHA Crossover  \
# 3AWFR000081       2.0                    NaN                    1.0
# 3BCCR001024       2.0                    NaN                    1.0
# 3BLFO000040       2.0                    NaN                    1.0
# 3BSLA000746       2.0                    1.0                    NaN
# 3CBSH000827       2.0                    1.0                    NaN
# 3CDMA000951       2.0                    1.0                    NaN
# 3EHRI000773       2.0                    NaN                    1.0
# 3FHGO000392       2.0                    1.0                    NaN
# 3JACA001152       2.0                    NaN                    1.0
# 3JMCO000722       2.0                    NaN                    1.0
# 3JRWE000881       2.0                    1.0                    NaN
# 3JXAL000304       2.0                    1.0                    NaN
# 3KXCH000169       2.0                    NaN                    1.0
# 3LDMO000125       2.0                    NaN                    1.0
# 3LDST000772       2.0                    NaN                    1.0
# 3MRHA001153       2.0                    1.0                    NaN
# 3PXMC001157       2.0                    NaN                    1.0
# 3RHHO001472       2.0                    NaN                    1.0
# 3RLSI001164       2.0                    1.0                    NaN
# 3TFBO000818       2.0                    NaN                    1.0
#
#              Ketogenic Diet
# 3AWFR000081             2.0
# 3BCCR001024             2.0
# 3BLFO000040             2.0
# 3BSLA000746             2.0
# 3CBSH000827             1.0
# 3CDMA000951             1.0
# 3EHRI000773             2.0
# 3FHGO000392             2.0
# 3JACA001152             2.0
# 3JMCO000722             1.0
# 3JRWE000881             2.0
# 3JXAL000304             2.0
# 3KXCH000169             2.0
# 3LDMO000125             2.0
# 3LDST000772             2.0
# 3MRHA001153             1.0
# 3PXMC001157             2.0
# 3RHHO001472             2.0
# 3RLSI001164             2.0
# 3TFBO000818             2.0

# %%
pd.DataFrame({t:tdf.first_diet.value_counts() for t, tdf in metadata_16S.groupby(['host_subject_id'])}).T
# Out:
#                1    2
# 3AWFR000081  5.0  NaN
# 3BCCR001024  5.0  NaN
# 3BLFO000040  5.0  NaN
# 3BSLA000746  NaN  5.0
# 3CBSH000827  NaN  4.0
# 3CDMA000951  NaN  4.0
# 3EHRI000773  5.0  NaN
# 3FHGO000392  NaN  5.0
# 3JACA001152  5.0  NaN
# 3JMCO000722  4.0  NaN
# 3JRWE000881  NaN  5.0
# 3JXAL000304  NaN  5.0
# 3KXCH000169  5.0  NaN
# 3LDMO000125  5.0  NaN
# 3LDST000772  5.0  NaN
# 3MRHA001153  NaN  4.0
# 3PXMC001157  5.0  NaN
# 3RHHO001472  5.0  NaN
# 3RLSI001164  NaN  5.0
# 3TFBO000818  5.0  NaN

# %%
sns.pointplot(y='first_diet', x='timepoint_encoded', hue='diet_nocross', data=metadata_16S)

plt.show()

# %%
# import 16S
bt = q2.Artifact.load('../data/metaG/wol_120644_feature-table.qza').view(Table)

# match the metadata 
shared_samples = set(bt.ids()) & set(metadata.index)
metadata_metag = metadata.copy().reindex(shared_samples)

# filte table
bt = bt.filter(shared_samples)

# filter and match the table
n_features, n_samples = bt.shape
min_feature_frequency = 0
min_feature_count = 0
min_sample_count = 100
def frequency_filter(val, id_, md):
    return (np.sum(val > 0) / n_samples) > (min_feature_frequency / 100)
def observation_filter(val, id_, md):
        return sum(val) > min_feature_count
bt = bt.filter(observation_filter, axis='observation')
bt = bt.filter(frequency_filter, axis='observation')
bt = bt.filter(bt.ids()[(bt.sum('sample') > min_sample_count)])

table = q2.Artifact.import_data('FeatureTable[Frequency]', bt)
table.save('../data/metaG/metaG-matched-table.qza')

with biom_open('../data/metaG/metaG-matched-table.biom', 'w') as f:
    table.view(Table).to_hdf5(f, "filt")

metadata_metag.to_csv('../data/metaG/metaG-matched-metadata.tsv', sep='\t')

metadata_metag.index = metadata_metag.index.astype(str)
metadata_metag = metadata_metag.drop(['dna_extracted','physical_specimen_remaining'], axis=1)
q2.Metadata(metadata_metag).save('../data/metaG/metaG-matched-metadata.qza')

bt
# Out:
# 5654 x 91 <class 'biom.table.Table'> with 175455 nonzero entries (34% dense)

# %%
sns.pointplot(y='first_diet', x='timepoint_encoded', hue='diet_nocross', data=metadata_metag)

plt.show()

# %% [markdown]
# # make stool subset for mmvec that is matched for metabolomics

# %%
# import L4 and L5 tables and match them and save
fecal_l4 = pd.read_csv('../data/metabolomics/BEAM_fecal_food_counts_L4.csv', index_col=0)
fecal_l4.index = ['13662.' + x.replace('.mzXML', '') for x in fecal_l4.index]
fecal_l4_16S = fecal_l4.reindex(metadata_16S.index)
fecal_l4_metag = fecal_l4.reindex(metadata_metag.index)

fecal_l4_16S = q2.Artifact.import_data('FeatureTable[Frequency]',
                                       Table(fecal_l4_16S.values.T,
                                             fecal_l4_16S.columns,
                                             fecal_l4_16S.index))
fecal_l4_16S.save('../data/metabolomics/matched-table-L4-16S.qza')

fecal_l4_metag = q2.Artifact.import_data('FeatureTable[Frequency]',
                                       Table(fecal_l4_metag.values.T,
                                             fecal_l4_metag.columns,
                                             fecal_l4_metag.index))
fecal_l4_metag.save('../data/metabolomics/matched-table-L4-metaG.qza')


fecal_l5 = pd.read_csv('../data/metabolomics/BEAM_fecal_food_counts_L5.csv', index_col=0)
fecal_l5.index = ['13662.' + x.replace('.mzXML', '') for x in fecal_l5.index]
fecal_l5_16S = fecal_l5.reindex(metadata_16S.index)
fecal_l5_metag = fecal_l5.reindex(metadata_metag.index)

fecal_l5_16S = q2.Artifact.import_data('FeatureTable[Frequency]',
                                       Table(fecal_l5_16S.values.T,
                                             fecal_l5_16S.columns,
                                             fecal_l5_16S.index))
fecal_l5_16S.save('../data/metabolomics/matched-table-L5-16S.qza')

fecal_l5_metag = q2.Artifact.import_data('FeatureTable[Frequency]',
                                       Table(fecal_l5_metag.values.T,
                                             fecal_l5_metag.columns,
                                             fecal_l5_metag.index))
fecal_l5_metag.save('../data/metabolomics/matched-table-L5-metaG.qza')


fecal_metaball = pd.read_excel('../data/metabolomics/BEAM_FBMN2_quant.xlsx', index_col=0)
fecal_metaball = fecal_metaball.drop(['row m/z','row retention time'], axis=1)
fecal_metaball.columns = [x.split(' ')[0] for x in fecal_metaball.columns]
fecal_metaball = fecal_metaball.T
fecal_metaball.index = ['13662.' + x.replace('.mzXML', '') for x in fecal_metaball.index]
fecal_metaball_16S = fecal_metaball.reindex(metadata_16S.index)
fecal_metaball_metag = fecal_metaball.reindex(metadata_metag.index)
fecal_metaball_16S = fecal_metaball_16S.loc[:, fecal_metaball_16S.sum(0) > 0]
fecal_metaball_metag = fecal_metaball_metag.loc[:, fecal_metaball_metag.sum(0) > 0]
fecal_metaball_metag.columns = 'f' + fecal_metaball_metag.columns.astype(str)
fecal_metaball_16S.columns = 'f' + fecal_metaball_16S.columns.astype(str)

fecal_metaball_16S = q2.Artifact.import_data('FeatureTable[Frequency]',
                                       Table(fecal_metaball_16S.values.T,
                                             fecal_metaball_16S.columns,
                                             fecal_metaball_16S.index))
fecal_metaball_16S.save('../data/metabolomics/matched-table-metaball-16S.qza')

fecal_metaball_metag = q2.Artifact.import_data('FeatureTable[Frequency]',
                                       Table(fecal_metaball_metag.values.T,
                                             fecal_metaball_metag.columns,
                                             fecal_metaball_metag.index))
fecal_metaball_metag.save('../data/metabolomics/matched-table-metaball-metaG.qza')

# make copies for metadata
metab_metadata_stool_subset_16S = metab_metadata_stool.copy()
metab_metadata_stool_subset_metaG = metab_metadata_stool.copy()

# match index w Qiita id
metab_metadata_stool_subset_16S.index = '13662.' + metab_metadata_stool_subset_16S.index
metab_metadata_stool_subset_metaG.index = '13662.' + metab_metadata_stool_subset_metaG.index
# match to each
metab_metadata_stool_subset_16S = metab_metadata_stool_subset_16S.reindex(metadata_16S.index)
metab_metadata_stool_subset_metaG = metab_metadata_stool_subset_metaG.reindex(metadata_metag.index)
metab_metadata_stool_subset_16S.to_csv('../data/metabolomics/matched-metadata-16S.tsv', sep='\t')
metab_metadata_stool_subset_metaG.to_csv('../data/metabolomics/matched-metadata-metaG.tsv', sep='\t')

# %%
serum_metaball = pd.read_excel('../data/metabolomics/BEAM_FBMN2_quant.xlsx', index_col=0)
serum_metaball = serum_metaball.drop(['row m/z','row retention time'], axis=1)
serum_metaball.columns = [x.split(' ')[0] for x in serum_metaball.columns]
serum_metaball = serum_metaball.T
serum_metaball.index = ['13662.' + x.replace('.mzXML', '') for x in serum_metaball.index]

# %%
metab_metadata_serum = metab_metadata[metab_metadata['Sample.Type'] == 'Serum']
metab_metadata_serum['StudyID'] = metab_metadata_serum.StudyID.astype(str)
metadata_metag_match = metadata_metag.copy()

metab_metadata_serum['orgind'] = metab_metadata_serum.index
metab_metadata_serum_match = metab_metadata_serum.set_index(['StudyID','Study_TP'])
metadata_metag_match = metadata_metag.set_index(['anonymized_name' ,'timepoint_encoded'])
metab_metadata_serum_match = pd.concat([metab_metadata_serum_match, metadata_metag_match], axis=1).dropna(subset=['diet_nocross'])
metab_metadata_serum_match
# Out:
# /Users/cmartino/miniconda3/envs/qiime2-2021.2.songbird.mmvec/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/cmartino/miniconda3/envs/qiime2-2021.2.songbird.mmvec/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#           Sample.Type    SubjectID  Status  First.Diet  Age  Gender  BMI_pbl  \
# 1263001 1       Serum  3AWFR000081       1           1   62       1    27.92
#         2       Serum  3AWFR000081       1           1   62       1    27.92
#         3       Serum  3AWFR000081       1           1   62       1    27.92
#         4       Serum  3AWFR000081       1           1   62       1    27.92
#         5       Serum  3AWFR000081       1           1   62       1    27.92
# ...               ...          ...     ...         ...  ...     ...      ...
# 1263039 1       Serum  3RHHO001472       1           1   67       1    24.35
#         2       Serum  3RHHO001472       1           1   67       1    24.35
#         3       Serum  3RHHO001472       1           1   67       1    24.35
#         4       Serum  3RHHO001472       1           1   67       1    24.35
#         5       Serum  3RHHO001472       1           1   67       1    24.35
#
#            MemDx Visit.Type.Stool  Visit.Date  ... stool_position  taxon_id  \
# 1263001 1  MCI-A            Pre 1  02/11/2015  ...              1  408170.0
#         2  MCI-A           Post 1   3/25/2015  ...              2  408170.0
#         3  MCI-A     FU 1 / Pre 2  05/07/2015  ...              3  408170.0
#         4  MCI-A           Post 2   6/22/2015  ...              4  408170.0
#         5  MCI-A             FU 2  08/04/2015  ...              5  408170.0
# ...          ...              ...         ...  ...            ...       ...
# 1263039 1    MCI            Pre 1  10/05/2016  ...             17  408170.0
#         2    MCI           Post 1  11/29/2016  ...             18  408170.0
#         3    MCI     FU 1 / Pre 2  01/09/2017  ...             19  408170.0
#         4    MCI           Post 2   2/20/2017  ...             20  408170.0
#         5    MCI             FU 2  04/04/2017  ...             21  408170.0
#
#               timepoint     title     tube_id uom visit_type  cog  \
# 1263001 1         Pre 1  BEAM_U19  0005555659  mg   PreA-Cog  MCI
#         2        Post 1  BEAM_U19  0005555660  mg  POSTA-COG  MCI
#         3  FU 1 / Pre 2  BEAM_U19  0005555661  mg   PREB-COG  MCI
#         4        Post 2  BEAM_U19  0005555662  mg  POSTB-COG  MCI
#         5          FU 2  BEAM_U19  0005555663  mg   POSTB-FU  MCI
# ...                 ...       ...         ...  ..        ...  ...
# 1263039 1         Pre 1  BEAM_U19  0005556907  mg   PreA-Cog  MCI
#         2        Post 1  BEAM_U19  0005556908  mg  POSTA-COG  MCI
#         3  FU 1 / Pre 2  BEAM_U19  0005556909  mg   PREB-COG  MCI
#         4        Post 2  BEAM_U19  0005556910  mg  POSTB-COG  MCI
#         5          FU 2  BEAM_U19  0005556911  mg   POSTB-FU  MCI
#
#                             diet    diet_nocross
# 1263001 1         Ketogenic Diet  Ketogenic Diet
#         2         Ketogenic Diet  Ketogenic Diet
#         3  Keto-to-AHA Crossover        AHA Diet
#         4               AHA Diet        AHA Diet
#         5               AHA Diet        AHA Diet
# ...                          ...             ...
# 1263039 1         Ketogenic Diet  Ketogenic Diet
#         2         Ketogenic Diet  Ketogenic Diet
#         3  Keto-to-AHA Crossover        AHA Diet
#         4               AHA Diet        AHA Diet
#         5               AHA Diet        AHA Diet
#
# [93 rows x 82 columns]

# %%
metadata_metag_match
# Out:
#                                   age bmi_pbl           box_name  \
# anonymized_name timepoint_encoded
# 1263001         2                  62   27.92  31102 Stool Box 1
# 1263024         3                  60      21  31102 Stool Box 1
# 1263034         1                  70   31.28  31102 Stool Box 2
# 1263019         4                  57   30.26  31102 Stool Box 1
# 1263028         1                  62      34  31102 Stool Box 2
# ...                                ..     ...                ...
# 1263032         4                  65   32.06  31102 Stool Box 2
# 1263007         1                  64    26.6  31102 Stool Box 1
# 1263028         2                  62      34  31102 Stool Box 2
# 1263020         5                  59   26.29  31102 Stool Box 1
# 1263021         2                  55   41.46  31102 Stool Box 1
#
#                                   cog_visit_date collection_timestamp  \
# anonymized_name timepoint_encoded
# 1263001         2                        3/24/15           2015-03-25
# 1263024         3                        4/13/16           2016-04-18
# 1263034         1                        4/22/16           2016-05-19
# 1263019         4                       11/23/15           2015-11-24
# 1263028         1                        4/19/16           2016-04-26
# ...                                          ...                  ...
# 1263032         4                        10/4/16           2016-10-04
# 1263007         1                         4/2/15           2015-04-08
# 1263028         2                        6/15/16           2016-06-22
# 1263020         5                         3/4/16           2016-03-11
# 1263021         2                       11/30/15           2015-12-01
#
#                                                              description  \
# anonymized_name timepoint_encoded
# 1263001         2                        fecal sample Post 1 3AWFR000081
# 1263024         3                  fecal sample FU 1 / Pre 2 3BCCR001024
# 1263034         1                         fecal sample Pre 2 3RLSI001164
# 1263019         4                        fecal sample Post 2 3LDMO000125
# 1263028         1                         fecal sample Pre 2 3JRWE000881
# ...                                                                  ...
# 1263032         4                        fecal sample Post 1 3MRHA001153
# 1263007         1                         fecal sample Pre 1 3BLFO000040
# 1263028         2                        fecal sample Post 2 3JRWE000881
# 1263020         5                          fecal sample FU 2 3KXCH000169
# 1263021         2                        fecal sample Post 2 3CDMA000951
#
#                                    elevation           empo_1  empo_2  \
# anonymized_name timepoint_encoded
# 1263001         2                        300  Host-associated  Animal
# 1263024         3                        300  Host-associated  Animal
# 1263034         1                        300  Host-associated  Animal
# 1263019         4                        300  Host-associated  Animal
# 1263028         1                        300  Host-associated  Animal
# ...                                      ...              ...     ...
# 1263032         4                        300  Host-associated  Animal
# 1263007         1                        300  Host-associated  Animal
# 1263028         2                        300  Host-associated  Animal
# 1263020         5                        300  Host-associated  Animal
# 1263021         2                        300  Host-associated  Animal
#
#                                               empo_3  ... stool_position  \
# anonymized_name timepoint_encoded                     ...
# 1263001         2                  Animal distal gut  ...              2
# 1263024         3                  Animal distal gut  ...             69
# 1263034         1                  Animal distal gut  ...             12
# 1263019         4                  Animal distal gut  ...             50
# 1263028         1                  Animal distal gut  ...              1
# ...                                              ...  ...            ...
# 1263032         4                  Animal distal gut  ...             11
# 1263007         1                  Animal distal gut  ...             11
# 1263028         2                  Animal distal gut  ...              2
# 1263020         5                  Animal distal gut  ...             56
# 1263021         2                  Animal distal gut  ...             58
#
#                                   taxon_id     timepoint     title  \
# anonymized_name timepoint_encoded
# 1263001         2                   408170        Post 1  BEAM_U19
# 1263024         3                   408170  FU 1 / Pre 2  BEAM_U19
# 1263034         1                   408170         Pre 2  BEAM_U19
# 1263019         4                   408170        Post 2  BEAM_U19
# 1263028         1                   408170         Pre 2  BEAM_U19
# ...                                    ...           ...       ...
# 1263032         4                   408170        Post 1  BEAM_U19
# 1263007         1                   408170         Pre 1  BEAM_U19
# 1263028         2                   408170        Post 2  BEAM_U19
# 1263020         5                   408170          FU 2  BEAM_U19
# 1263021         2                   408170        Post 2  BEAM_U19
#
#                                       tube_id uom visit_type  cog  \
# anonymized_name timepoint_encoded
# 1263001         2                  0005555660  mg  POSTA-COG  MCI
# 1263024         3                  0005556816  mg   PREB-COG   NC
# 1263034         1                  0005556892  mg   PREA-COG  MCI
# 1263019         4                  0005556748  mg  POSTB-COG  MCI
# 1263028         1                  0005556859  mg   PREA-COG  MCI
# ...                                       ...  ..        ...  ...
# 1263032         4                  0005556883  mg  POSTB-COG  MCI
# 1263007         1                  0005556637  mg   PREA-COG  MCI
# 1263028         2                  0005556860  mg  POSTA-COG  MCI
# 1263020         5                  0005556764  mg   POSTB-FU  MCI
# 1263021         2                  0005556776  mg  POSTA-COG   NC
#
#                                                     diet    diet_nocross
# anonymized_name timepoint_encoded
# 1263001         2                         Ketogenic Diet  Ketogenic Diet
# 1263024         3                  Keto-to-AHA Crossover        AHA Diet
# 1263034         1                               AHA Diet        AHA Diet
# 1263019         4                               AHA Diet        AHA Diet
# 1263028         1                               AHA Diet        AHA Diet
# ...                                                  ...             ...
# 1263032         4                         Ketogenic Diet  Ketogenic Diet
# 1263007         1                         Ketogenic Diet  Ketogenic Diet
# 1263028         2                               AHA Diet        AHA Diet
# 1263020         5                               AHA Diet        AHA Diet
# 1263021         2                               AHA Diet        AHA Diet
#
# [93 rows x 59 columns]

# %%
metab_metadata_serum['Study_TP'].value_counts()
# Out:
# 4    20
# 3    20
# 2    20
# 1    20
# 5    18
# Name: Study_TP, dtype: int64

# %%
# Out:
#                                   age bmi_pbl           box_name  \
# anonymized_name timepoint_encoded
# 1263024         2                  60      21  31102 Stool Box 1
# 1263011         2                  63   22.26  31102 Stool Box 1
# 1263017         3                  66    27.8  31102 Stool Box 1
# 1263021         2                  55   41.46  31102 Stool Box 1
# 1263019         5                  57   30.26  31102 Stool Box 1
# ...                                ..     ...                ...
# 1263001         4                  62   27.92  31102 Stool Box 1
# 1263009         5                  67   31.24  31102 Stool Box 1
# 1263013         2                  72    22.6  31102 Stool Box 1
# 1263021         4                  55   41.46  31102 Stool Box 1
# 1263007         1                  64    26.6  31102 Stool Box 1
#
#                                   cog_visit_date collection_timestamp  \
# anonymized_name timepoint_encoded
# 1263024         2                        2/25/16           2016-02-23
# 1263011         2                        6/11/15           2015-06-17
# 1263017         3                        3/28/16           2016-03-28
# 1263021         2                       11/30/15           2015-12-01
# 1263019         5                        1/12/16           2016-01-28
# ...                                          ...                  ...
# 1263001         4                        6/17/15           2015-06-22
# 1263009         5                       10/15/15           2015-11-18
# 1263013         2                        7/17/15           2015-07-20
# 1263021         4                        2/29/16           2016-03-01
# 1263007         1                         4/2/15           2015-04-08
#
#                                                              description  \
# anonymized_name timepoint_encoded
# 1263024         2                        fecal sample Post 1 3BCCR001024
# 1263011         2                        fecal sample Post 2 3BSLA000746
# 1263017         3                  fecal sample FU 1 / Pre 2 3TFBO000818
# 1263021         2                        fecal sample Post 2 3CDMA000951
# 1263019         5                          fecal sample FU 2 3LDMO000125
# ...                                                                  ...
# 1263001         4                        fecal sample Post 2 3AWFR000081
# 1263009         5                          fecal sample FU 2 3JMCO000722
# 1263013         2                        fecal sample Post 1 3EHRI000773
# 1263021         4                        fecal sample Post 1 3CDMA000951
# 1263007         1                         fecal sample Pre 1 3BLFO000040
#
#                                    elevation           empo_1  empo_2  \
# anonymized_name timepoint_encoded
# 1263024         2                        300  Host-associated  Animal
# 1263011         2                        300  Host-associated  Animal
# 1263017         3                        300  Host-associated  Animal
# 1263021         2                        300  Host-associated  Animal
# 1263019         5                        300  Host-associated  Animal
# ...                                      ...              ...     ...
# 1263001         4                        300  Host-associated  Animal
# 1263009         5                        300  Host-associated  Animal
# 1263013         2                        300  Host-associated  Animal
# 1263021         4                        300  Host-associated  Animal
# 1263007         1                        300  Host-associated  Animal
#
#                                               empo_3  ... stool_position  \
# anonymized_name timepoint_encoded                     ...
# 1263024         2                  Animal distal gut  ...             68
# 1263011         2                  Animal distal gut  ...             22
# 1263017         3                  Animal distal gut  ...             39
# 1263021         2                  Animal distal gut  ...             58
# 1263019         5                  Animal distal gut  ...             51
# ...                                              ...  ...            ...
# 1263001         4                  Animal distal gut  ...              4
# 1263009         5                  Animal distal gut  ...             20
# 1263013         2                  Animal distal gut  ...             28
# 1263021         4                  Animal distal gut  ...             60
# 1263007         1                  Animal distal gut  ...             11
#
#                                   taxon_id     timepoint     title  \
# anonymized_name timepoint_encoded
# 1263024         2                   408170        Post 1  BEAM_U19
# 1263011         2                   408170        Post 2  BEAM_U19
# 1263017         3                   408170  FU 1 / Pre 2  BEAM_U19
# 1263021         2                   408170        Post 2  BEAM_U19
# 1263019         5                   408170          FU 2  BEAM_U19
# ...                                    ...           ...       ...
# 1263001         4                   408170        Post 2  BEAM_U19
# 1263009         5                   408170          FU 2  BEAM_U19
# 1263013         2                   408170        Post 1  BEAM_U19
# 1263021         4                   408170        Post 1  BEAM_U19
# 1263007         1                   408170         Pre 1  BEAM_U19
#
#                                       tube_id uom visit_type  cog  \
# anonymized_name timepoint_encoded
# 1263024         2                  0005556815  mg  POSTA-COG   NC
# 1263011         2                  0005556668  mg  POSTA-COG   NC
# 1263017         3                  0005556717  mg   PREB-COG   NC
# 1263021         2                  0005556776  mg  POSTA-COG   NC
# 1263019         5                  0005556749  mg   POSTB-FU  MCI
# ...                                       ...  ..        ...  ...
# 1263001         4                  0005555662  mg  POSTB-COG  MCI
# 1263009         5                  0005556656  mg   POSTB-FU   NC
# 1263013         2                  0005556686  mg  POSTA-COG   NC
# 1263021         4                  0005556778  mg  POSTB-COG   NC
# 1263007         1                  0005556637  mg   PREA-COG  MCI
#
#                                                     diet    diet_nocross
# anonymized_name timepoint_encoded
# 1263024         2                         Ketogenic Diet  Ketogenic Diet
# 1263011         2                               AHA Diet        AHA Diet
# 1263017         3                  Keto-to-AHA Crossover        AHA Diet
# 1263021         2                               AHA Diet        AHA Diet
# 1263019         5                               AHA Diet        AHA Diet
# ...                                                  ...             ...
# 1263001         4                               AHA Diet        AHA Diet
# 1263009         5                               AHA Diet        AHA Diet
# 1263013         2                         Ketogenic Diet  Ketogenic Diet
# 1263021         4                         Ketogenic Diet  Ketogenic Diet
# 1263007         1                         Ketogenic Diet  Ketogenic Diet
#
# [93 rows x 59 columns]

# %%
set(metadata_metag.anonymized_name) & set(metab_metadata_serum.StudyID.astype(str))
# Out:
# {'1263001',
#  '1263002',
#  '1263007',
#  '1263009',
#  '1263011',
#  '1263013',
#  '1263016',
#  '1263017',
#  '1263018',
#  '1263019',
#  '1263020',
#  '1263021',
#  '1263023',
#  '1263024',
#  '1263026',
#  '1263027',
#  '1263028',
#  '1263032',
#  '1263034',
#  '1263039'}

# %%
metadata_metag.anonymized_name.value_counts()
# Out:
# 1263007    5
# 1263018    5
# 1263024    5
# 1263020    5
# 1263016    5
# 1263001    5
# 1263023    5
# 1263011    5
# 1263009    5
# 1263013    5
# 1263026    5
# 1263002    5
# 1263039    5
# 1263019    5
# 1263017    5
# 1263021    4
# 1263028    4
# 1263034    4
# 1263027    4
# 1263032    2
# Name: anonymized_name, dtype: int64

# %%
metab_metadata_serum.StudyID.value_counts()
# Out:
# 1263039    5
# 1263034    5
# 1263002    5
# 1263007    5
# 1263009    5
# 1263011    5
# 1263013    5
# 1263016    5
# 1263017    5
# 1263018    5
# 1263019    5
# 1263020    5
# 1263023    5
# 1263024    5
# 1263026    5
# 1263027    5
# 1263028    5
# 1263001    5
# 1263021    4
# 1263032    4
# Name: StudyID, dtype: int64

# %%
serum_metaball
# Out:
# row ID                1             2             3             4      \
# 13662.5556614  2.385536e+09  1.482022e+09  1.559497e+09  1.636384e+09
# 13662.5556617  2.534247e+09  1.351339e+09  1.632058e+09  1.574368e+09
# 13662.5556637  2.221881e+09  1.670554e+09  1.434212e+09  1.688140e+09
# 13662.5555660  2.663278e+09  1.271660e+09  1.812261e+09  1.330980e+09
# 13662.5555659  2.480597e+09  1.692069e+09  1.617153e+09  1.049752e+09
# ...                     ...           ...           ...           ...
# 13662.5556860  1.562763e+09  1.980098e+09  9.891450e+08  2.304924e+09
# 13662.5556893  2.848567e+09  1.693485e+09  1.877038e+09  6.762344e+08
# 13662.5556862  3.149825e+09  0.000000e+00  1.996296e+09  3.254721e+09
# 13662.5556881  4.488715e+09  0.000000e+00  2.859373e+09  1.210617e+09
# 13662.5556874  1.517657e+09  0.000000e+00  9.692537e+08  2.327615e+09
#
# row ID                5             6             7             8      \
# 13662.5556614  1.018266e+09  1.006894e+09  7.396123e+08  4.604163e+08
# 13662.5556617  9.713978e+08  9.411820e+08  6.381021e+08  4.222134e+08
# 13662.5556637  1.027367e+09  1.036161e+09  7.779681e+08  7.704731e+08
# 13662.5555660  7.926265e+08  7.906243e+08  5.349039e+08  8.956832e+08
# 13662.5555659  6.510921e+08  6.536944e+08  7.986850e+08  1.521409e+09
# ...                     ...           ...           ...           ...
# 13662.5556860  1.421434e+09  1.409878e+09  9.508420e+08  7.505008e+08
# 13662.5556893  4.178861e+08  4.137672e+08  8.165878e+08  2.642816e+08
# 13662.5556862  1.995785e+09  1.967746e+09  7.988659e+08  4.959722e+08
# 13662.5556881  7.657432e+08  7.370656e+08  5.446673e+08  2.443257e+08
# 13662.5556874  1.447961e+09  1.425097e+09  8.250724e+08  3.173520e+08
#
# row ID                9             10     ...         13947  13948  \
# 13662.5556614  9.170889e+08  7.792449e+08  ...  0.000000e+00    0.0
# 13662.5556617  9.574292e+08  6.543436e+08  ...  0.000000e+00    0.0
# 13662.5556637  6.648388e+08  9.105135e+08  ...  0.000000e+00    0.0
# 13662.5555660  5.233659e+08  6.245578e+08  ...  0.000000e+00    0.0
# 13662.5555659  4.866587e+08  8.116878e+08  ...  0.000000e+00    0.0
# ...                     ...           ...  ...           ...    ...
# 13662.5556860  7.444888e+08  9.664696e+08  ...  0.000000e+00    0.0
# 13662.5556893  5.344825e+08  6.382703e+08  ...  3.108811e+06    0.0
# 13662.5556862  1.059163e+09  7.493403e+08  ...  0.000000e+00    0.0
# 13662.5556881  6.428335e+08  5.228090e+08  ...  0.000000e+00    0.0
# 13662.5556874  1.062840e+09  9.798881e+08  ...  0.000000e+00    0.0
#
# row ID                13949         13950         13951         13952  \
# 13662.5556614  0.000000e+00  0.000000e+00       0.00000  0.000000e+00
# 13662.5556617  0.000000e+00  0.000000e+00       0.00000  0.000000e+00
# 13662.5556637  0.000000e+00  0.000000e+00       0.00000  0.000000e+00
# 13662.5555660  0.000000e+00  0.000000e+00       0.00000  0.000000e+00
# 13662.5555659  0.000000e+00  0.000000e+00       0.00000  0.000000e+00
# ...                     ...           ...           ...           ...
# 13662.5556860  0.000000e+00  0.000000e+00       0.00000  0.000000e+00
# 13662.5556893  7.542341e+07  0.000000e+00  423883.07182  6.394232e+06
# 13662.5556862  0.000000e+00  6.263888e+06       0.00000  0.000000e+00
# 13662.5556881  0.000000e+00  0.000000e+00       0.00000  6.954963e+06
# 13662.5556874  7.225664e+07  2.761611e+06       0.00000  0.000000e+00
#
# row ID                13953         13954         13955         13956
# 13662.5556614       0.00000  0.000000e+00  0.000000e+00  0.000000e+00
# 13662.5556617       0.00000  0.000000e+00  0.000000e+00  0.000000e+00
# 13662.5556637       0.00000  0.000000e+00  0.000000e+00  0.000000e+00
# 13662.5555660       0.00000  0.000000e+00  0.000000e+00  0.000000e+00
# 13662.5555659       0.00000  0.000000e+00  0.000000e+00  0.000000e+00
# ...                     ...           ...           ...           ...
# 13662.5556860  458198.18782  0.000000e+00  0.000000e+00  0.000000e+00
# 13662.5556893       0.00000  9.903128e+05  0.000000e+00  2.974490e+06
# 13662.5556862       0.00000  9.701775e+05  0.000000e+00  1.592788e+05
# 13662.5556881       0.00000  1.995180e+06  2.798863e+07  2.096740e+06
# 13662.5556874       0.00000  0.000000e+00  1.462685e+07  3.383856e+06
#
# [102 rows x 13956 columns]

# %%
fecal_metaball_16S.view(Table)
# Out:
# 13956 x 96 <class 'biom.table.Table'> with 396743 nonzero entries (29% dense)

# %%
fecal_l4_16S.view(Table)
# Out:
# 44 x 96 <class 'biom.table.Table'> with 3044 nonzero entries (72% dense)

# %%
fecal_l5_16S.view(Table)
# Out:
# 108 x 96 <class 'biom.table.Table'> with 5128 nonzero entries (49% dense)

# %%
fecal_metaball_metag.view(Table)
# Out:
# 13954 x 93 <class 'biom.table.Table'> with 384145 nonzero entries (29% dense)

# %%
fecal_l4_metag.view(Table)
# Out:
# 44 x 93 <class 'biom.table.Table'> with 2936 nonzero entries (71% dense)

# %%
fecal_l5_metag.view(Table)
# Out:
# 108 x 93 <class 'biom.table.Table'> with 4947 nonzero entries (49% dense)
